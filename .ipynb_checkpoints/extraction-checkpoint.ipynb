# %% [markdown]
# ## Installing some of the dependencies

# %%
! pip install psycopg2 
! pip install requests
! pip install SQLAlchemy
# Out:
# Requirement already satisfied: psycopg2 in /opt/anaconda3/lib/python3.12/site-packages (2.9.10)
# Requirement already satisfied: requests in /opt/anaconda3/lib/python3.12/site-packages (2.32.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.12/site-packages (from requests) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.12/site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.12/site-packages (from requests) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.12/site-packages (from requests) (2024.8.30)
# Requirement already satisfied: SQLAlchemy in /opt/anaconda3/lib/python3.12/site-packages (2.0.30)
# Requirement already satisfied: typing-extensions>=4.6.0 in /opt/anaconda3/lib/python3.12/site-packages (from SQLAlchemy) (4.11.0)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/anaconda3/lib/python3.12/site-packages (from SQLAlchemy) (3.0.1)

# %% [markdown]
# # Importing dependencies

# %%
import pandas as pd
import numpy
import requests
import json
import csv

# %% [markdown]
# # Extraction Layer: Extracting the dataset from RapidAPI

# %%
url = "https://realty-mole-property-api.p.rapidapi.com/randomProperties"

querystring = {"limit":"100000"}

headers = {
	"x-rapidapi-key": "ce3693686amshd8a81ba62ce435ep1113afjsn137d2b9aa172",
	"x-rapidapi-host": "realty-mole-property-api.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

data = response.json()


# saving the data as a file

filename = 'propertyRecords.json'

# to write the file into the filename
with open (filename, 'w') as file:
    json.dump(data,file, indent = 4)

# %%
# to read into a dataframe

propertyrecords_df = pd.read_json('propertyRecords.json')

# %% [markdown]
# # Transforming the dataset

# %%
propertyrecords_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 27 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   bathrooms         371 non-null    float64
#  1   bedrooms          332 non-null    float64
#  2   county            499 non-null    object
#  3   propertyType      413 non-null    object
#  4   addressLine1      500 non-null    object
#  5   city              500 non-null    object
#  6   state             500 non-null    object
#  7   zipCode           500 non-null    int64
#  8   formattedAddress  500 non-null    object
#  9   assessorID        345 non-null    object
#  10  legalDescription  335 non-null    object
#  11  squareFootage     378 non-null    float64
#  12  subdivision       292 non-null    object
#  13  yearBuilt         365 non-null    float64
#  14  zoning            183 non-null    object
#  15  lotSize           343 non-null    float64
#  16  lastSalePrice     255 non-null    float64
#  17  lastSaleDate      308 non-null    object
#  18  features          445 non-null    object
#  19  taxAssessment     340 non-null    object
#  20  propertyTaxes     332 non-null    object
#  21  owner             342 non-null    object
#  22  id                500 non-null    object
#  23  longitude         500 non-null    float64
#  24  latitude          500 non-null    float64
#  25  addressLine2      112 non-null    object
#  26  ownerOccupied     310 non-null    float64
# dtypes: float64(9), int64(1), object(17)
# memory usage: 105.6+ KB

# %%
# Extract taxAssessment2021_Value
propertyrecords_df['taxAssessment2021_Values'] = propertyrecords_df['taxAssessment'].apply(
    lambda x: x['2021']['value'] if isinstance(x, dict) and '2021' in x and isinstance(x['2021'], dict) else None
)

# Extract propertyTaxes2021_Total
propertyrecords_df['propertyTaxes2021_Total'] = propertyrecords_df['propertyTaxes'].apply(
    lambda x: x['2021']['total'] if isinstance(x, dict) and '2021' in x and isinstance(x['2021'], dict) else None
)

propertyrecords_df['taxAssessment2022_Values'] = propertyrecords_df['taxAssessment'].apply(
    lambda x: x['2022']['value'] if isinstance(x, dict) and '2022' in x and isinstance(x['2022'], dict) else None
)

# Extract propertyTaxes2021_Total
propertyrecords_df['propertyTaxes2022_Total'] = propertyrecords_df['propertyTaxes'].apply(
    lambda x: x['2022']['total'] if isinstance(x, dict) and '2022' in x and isinstance(x['2022'], dict) else None
)

# %%
# Safely extract taxAssessment2023_Values
propertyrecords_df['taxAssessment2023_Values'] = propertyrecords_df['taxAssessment'].apply(
    lambda x: x.get('2023', {}).get('value') if isinstance(x, dict) else None
)

# Safely extract propertyTaxes2023_Total
propertyrecords_df['propertyTaxes2023_Total'] = propertyrecords_df['propertyTaxes'].apply(
    lambda x: x.get('2023', {}).get('total') if isinstance(x, dict) else None
)

# %%
# approach of cleaning
propertyrecords_df['ownerName'] = propertyrecords_df['owner'].apply(lambda x: x['names'][0] if isinstance(x, dict) and isinstance(x['names'], list) and x['names'] else None)


propertyrecords_df['features'] = propertyrecords_df['features'].apply(json.dumps)

# second approach to find and replace the nulls
propertyrecords_df.fillna({
        'bedrooms': 0,
        'ownerNames':  'Unknown',
        'addressLine2': 'Not available', 
        'squareFootage': 0,
        'yearBuilt': 0,
        'features': 'None',
        'assessorID': 'Unknown',
        'legalDescription': 'Not available',
        'subdivision': 'Not available', 
         'zoning': 'Unknown', 
         'bathrooms': 0, 
         'lotSize': 0,
         'propertyType': 'Unknown', 
         'taxAssessment': 'Not available',
        'propertyTaxes':  'Not available', 
         'lastSalePrice': 0,
        'lastSaleDate': 0,
        'ownerOccupied': 0,
        'addressLine2': 'Unknown',
        'county': 'Not available'}, inplace =True)

# to extract the id from the address
propertyrecords_df['id'] = propertyrecords_df['id'].apply(lambda x: id(x))

# %%
propertyrecords_df['lastSaleDate'] = propertyrecords_df['lastSaleDate'].replace("Not available", pd.NaT)
#df['date_column'] = pd.to_datetime(df['date_column'], format="%Y-%m-%dT%H:%M:%S.%f%z", errors='coerce')

propertyrecords_df['lastSaleDate'] = pd.to_datetime(propertyrecords_df['lastSaleDate'],format="%Y-%m-%dT%H:%M:%S.%f%z", errors='coerce')

# %%
import datetime as dt

propertyrecords_df['year'] = propertyrecords_df['lastSaleDate'].dt.year
propertyrecords_df['month'] = propertyrecords_df['lastSaleDate'].dt.month
propertyrecords_df['monthName'] = propertyrecords_df['lastSaleDate'].dt.month_name()
propertyrecords_df['quarter'] = propertyrecords_df['lastSaleDate'].dt.quarter

# %%
propertyrecords_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 38 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   bathrooms                 500 non-null    float64
#  1   bedrooms                  500 non-null    float64
#  2   county                    500 non-null    object
#  3   propertyType              500 non-null    object
#  4   addressLine1              500 non-null    object
#  5   city                      500 non-null    object
#  6   state                     500 non-null    object
#  7   zipCode                   500 non-null    int64
#  8   formattedAddress          500 non-null    object
#  9   assessorID                500 non-null    object
#  10  legalDescription          500 non-null    object
#  11  squareFootage             500 non-null    float64
#  12  subdivision               500 non-null    object
#  13  yearBuilt                 500 non-null    float64
#  14  zoning                    500 non-null    object
#  15  lotSize                   500 non-null    float64
#  16  lastSalePrice             500 non-null    float64
#  17  lastSaleDate              308 non-null    datetime64[ns, UTC]
#  18  features                  500 non-null    object
#  19  taxAssessment             500 non-null    object
#  20  propertyTaxes             500 non-null    object
#  21  owner                     342 non-null    object
#  22  id                        500 non-null    int64
#  23  longitude                 500 non-null    float64
#  24  latitude                  500 non-null    float64
#  25  addressLine2              500 non-null    object
#  26  ownerOccupied             500 non-null    float64
#  27  taxAssessment2021_Values  81 non-null     float64
#  28  propertyTaxes2021_Total   67 non-null     float64
#  29  taxAssessment2022_Values  179 non-null    float64
#  30  propertyTaxes2022_Total   195 non-null    float64
#  31  taxAssessment2023_Values  227 non-null    float64
#  32  propertyTaxes2023_Total   190 non-null    float64
#  33  ownerName                 342 non-null    object
#  34  year                      308 non-null    float64
#  35  month                     308 non-null    float64
#  36  monthName                 308 non-null    object
#  37  quarter                   308 non-null    float64
# dtypes: datetime64[ns, UTC](1), float64(18), int64(2), object(17)
# memory usage: 148.6+ KB

# %%
features_dim = propertyrecords_df[['features', 'propertyType', 'zoning']].drop_duplicates().reset_index(drop=True)
features_dim['features_id'] = features_dim.index +1
propertyrecords_df = propertyrecords_df.merge(
    features_dim[['features_id','features', 'propertyType', 'zoning']],  # Bring sales_id into propertyrecords_df
    on=['features', 'propertyType', 'zoning'],  # Match on shared columns
    how='left'
)
features_dim
# Out:
#                                               features   propertyType  \
# 0    {"architectureType": "Conventional", "cooling"...  Single Family
# 1                                                   {}        Unknown
# 2                                                  NaN  Single Family
# 3    {"cooling": true, "coolingType": "Central", "e...  Single Family
# 4    {"cooling": true, "coolingType": "Central", "e...      Townhouse
# ..                                                 ...            ...
# 337  {"architectureType": "Condo / Apartment", "ext...  Single Family
# 338  {"garage": true, "garageType": "Garage", "unit...  Single Family
# 339  {"cooling": true, "coolingType": "Commercial",...  Single Family
# 340  {"architectureType": "Ranch", "cooling": true,...  Single Family
# 341  {"exteriorType": "Concrete Block", "floorCount...  Single Family
#
#                       zoning  features_id
# 0          SF-4 INDIAN TRAIL            1
# 1                    Unknown            2
# 2                    Unknown            3
# 3                         RL            4
# 4                      PD/AN            5
# ..                       ...          ...
# 337                     RSA4          338
# 338                  Unknown          339
# 339                      R1A          340
# 340                      R-1          341
# 341  0100:SINGLE FAM,GENERAL          342
#
# [342 rows x 4 columns]

# %%
legal_dim = propertyrecords_df[['legalDescription', 'subdivision']].drop_duplicates().reset_index(drop=True)
legal_dim['legal_id'] = legal_dim.index +1
propertyrecords_df = propertyrecords_df.merge(
    legal_dim[['legal_id','legalDescription', 'subdivision']],  # Bring sales_id into propertyrecords_df
    on=['legalDescription', 'subdivision'],  # Match on shared columns
    how='left'
)
legal_dim
# Out:
#                                       legalDescription  \
# 0                             #9 CARLISLE@BRANDON OAKS
# 1                                        Not available
# 2                                 CURTIS SD LOTS 5 & 6
# 3       VILLAGEWALK AT LAKE NONA UNIT 4A 77/57 LOT 199
# 4                           CORDOVA ESTATES MCR 574-01
# ..                                                 ...
# 332                                     120'1/4  NW PT
# 333                         LOT 2 BLK 1 MOORE ADDITION
# 334                     DISTRICT: 03, COUNTY AREA: L32
# 335  T1N, R10E, SEC 34 SUPERVISOR'S PLAT OF EVERGRE...
# 336  THE TROPICS AMD PL PB 10-17 LOT 4 BLK 101 LOT ...
#
#                         subdivision  legal_id
# 0           BRANDON OAKS - CARLISLE         1
# 1                     Not available         2
# 2                         CURTIS SD         3
# 3    VILLAGEWALK AT LAKE NONA UT 4A         4
# 4                   CORDOVA ESTATES         5
# ..                              ...       ...
# 332             NOWARD BUILDERS INC       333
# 333                       MOORE ADD       334
# 334       HAMILTON SPRINGS SEC1 PH3       335
# 335     SUPRVRS OF EVERGREEN PARK 1       336
# 336                     TROPICS AMD       337
#
# [337 rows x 3 columns]

# %%
location_dim = propertyrecords_df[['county','zipCode','formattedAddress','state','city']].drop_duplicates().reset_index(drop=True)
location_dim['location_id'] = location_dim.index +1

propertyrecords_df = propertyrecords_df.merge(
    location_dim[['location_id','county','zipCode','formattedAddress','state','city']],  # Bring sales_id into propertyrecords_df
    on=['county','zipCode','formattedAddress','state','city'],  # Match on shared columns
    how='left'
)
location_dim
# Out:
#            county  zipCode                                 formattedAddress  \
# 0           Union    28079          939 Ashburne Pl, Indian Trail, NC 28079
# 1          Warren    16365                  7 Jackson Ave, Warren, PA 16365
# 2    Henry County    47360     4747 N County Rd, 625 E, Mooreland, IN 47360
# 3          Dupage    60106     1440 W Irving Park Rd, Bensenville, IL 60106
# 4    Iosco County    48739                 4959 Franklin St, Hale, MI 48739
# ..            ...      ...                                              ...
# 495      Columbia    30814             873 Sweetgrass Cir, Harlem, GA 30814
# 496       Johnson    76093  504 Fishermans Paradise Rd, Rio Vista, TX 76093
# 497        Wilson    37087             307 Charleston St, Lebanon, TN 37087
# 498       Oakland    48075             20195 Mada Ave, Southfield, MI 48075
# 499    Miami-Dade    33147                2978 Nw 101st St, Miami, FL 33147
#
#     state          city  location_id
# 0      NC  Indian Trail            1
# 1      PA        Warren            2
# 2      IN     Mooreland            3
# 3      IL   Bensenville            4
# 4      MI          Hale            5
# ..    ...           ...          ...
# 495    GA        Harlem          496
# 496    TX     Rio Vista          497
# 497    TN       Lebanon          498
# 498    MI    Southfield          499
# 499    FL         Miami          500
#
# [500 rows x 6 columns]

# %%
date_dim = propertyrecords_df[['lastSaleDate', 'year', 'month',	'monthName', 'quarter']].drop_duplicates().reset_index(drop=True)
date_dim['date_id'] = date_dim.index +1

propertyrecords_df = propertyrecords_df.merge(
    date_dim[['date_id','lastSaleDate', 'year', 'month',	'monthName', 'quarter']],  # Bring sales_id into propertyrecords_df
    on=['lastSaleDate', 'year', 'month',	'monthName', 'quarter'],  # Match on shared columns
    how='left'
)
date_dim
# Out:
#                  lastSaleDate    year  month  monthName  quarter  date_id
# 0   2017-08-18 00:00:00+00:00  2017.0    8.0     August      3.0        1
# 1                         NaT     NaN    NaN        NaN      NaN        2
# 2   2017-08-17 00:00:00+00:00  2017.0    8.0     August      3.0        3
# 3   2021-02-03 00:00:00+00:00  2021.0    2.0   February      1.0        4
# 4   2013-10-11 00:00:00+00:00  2013.0   10.0    October      4.0        5
# ..                        ...     ...    ...        ...      ...      ...
# 293 2006-07-20 00:00:00+00:00  2006.0    7.0       July      3.0      294
# 294 1971-09-30 00:00:00+00:00  1971.0    9.0  September      3.0      295
# 295 2015-09-23 00:00:00+00:00  2015.0    9.0  September      3.0      296
# 296 2020-02-25 00:00:00+00:00  2020.0    2.0   February      1.0      297
# 297 2011-09-19 00:00:00+00:00  2011.0    9.0  September      3.0      298
#
# [298 rows x 6 columns]

# %%
owner_dim = propertyrecords_df[['ownerName','ownerOccupied']].drop_duplicates().reset_index(drop=True)
owner_dim['owner_id'] = owner_dim.index +1
# Merge features_dim into propertyrecords_df
propertyrecords_df = propertyrecords_df.merge(
    owner_dim[['owner_id','ownerName','ownerOccupied']],  # Use 'feature_id' consistently
    on=['ownerName','ownerOccupied'],  # Match on shared columns
    how='left'
)
owner_dim
# Out:
#                        ownerName  ownerOccupied  owner_id
# 0    IH6 PROPERTY NORTH CAROLINA            0.0         1
# 1                           None            0.0         2
# 2                 David M Wilcox            1.0         3
# 3     MANDLA BALA MURAIL KRISHNA            0.0         4
# 4       IH3 PROPERTY PHOENIX L P            0.0         5
# ..                           ...            ...       ...
# 336       Cleave Carolann M John            1.0       337
# 337                      3P LAND            0.0       338
# 338                 ROY J MILLER            1.0       339
# 339               Megan Farenger            1.0       340
# 340              VICTOR LELESTIN            1.0       341
#
# [341 rows x 3 columns]

# %%
print(propertyrecords_df['features_id'])
# Out:
# 0        1
# 1        2
# 2        3
# 3        2
# 4        3
#       ...
# 495      3
# 496    339
# 497    340
# 498    341
# 499    342
# Name: features_id, Length: 500, dtype: int64

# %%
propertyrecords_df.columns
# Out:
# Index(['bathrooms', 'bedrooms', 'county', 'propertyType', 'addressLine1',
#        'city', 'state', 'zipCode', 'formattedAddress', 'assessorID',
#        'legalDescription', 'squareFootage', 'subdivision', 'yearBuilt',
#        'zoning', 'lotSize', 'lastSalePrice', 'lastSaleDate', 'features',
#        'taxAssessment', 'propertyTaxes', 'owner', 'id', 'longitude',
#        'latitude', 'addressLine2', 'ownerOccupied', 'taxAssessment2021_Values',
#        'propertyTaxes2021_Total', 'taxAssessment2022_Values',
#        'propertyTaxes2022_Total', 'taxAssessment2023_Values',
#        'propertyTaxes2023_Total', 'ownerName', 'year', 'month', 'monthName',
#        'quarter', 'features_id', 'legal_id', 'location_id', 'date_id',
#        'owner_id'],
#       dtype='object')

# %%
fact_columns = ['id', 'date_id','features_id','location_id','owner_id','legal_id','bedrooms', 'squareFootage','bathrooms', 'lotSize','lastSalePrice','taxAssessment2021_Values','propertyTaxes2021_Total',
                'taxAssessment2022_Values', 'propertyTaxes2022_Total','taxAssessment2023_Values', 'propertyTaxes2023_Total', 'longitude', 'latitude']
fact_table = propertyrecords_df[fact_columns]

# %%
fact_table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id                        500 non-null    int64
#  1   date_id                   500 non-null    int64
#  2   features_id               500 non-null    int64
#  3   location_id               500 non-null    int64
#  4   owner_id                  500 non-null    int64
#  5   legal_id                  500 non-null    int64
#  6   bedrooms                  500 non-null    float64
#  7   squareFootage             500 non-null    float64
#  8   bathrooms                 500 non-null    float64
#  9   lotSize                   500 non-null    float64
#  10  lastSalePrice             500 non-null    float64
#  11  taxAssessment2021_Values  81 non-null     float64
#  12  propertyTaxes2021_Total   67 non-null     float64
#  13  taxAssessment2022_Values  179 non-null    float64
#  14  propertyTaxes2022_Total   195 non-null    float64
#  15  taxAssessment2023_Values  227 non-null    float64
#  16  propertyTaxes2023_Total   190 non-null    float64
#  17  longitude                 500 non-null    float64
#  18  latitude                  500 non-null    float64
# dtypes: float64(13), int64(6)
# memory usage: 74.3 KB

# %%
# saving dataset as csv
fact_table.to_csv('property_fact.csv', index=False)
owner_dim.to_csv('owners.csv', index=False)
legal_dim.to_csv('legal.csv', index=False)
location_dim.to_csv('location_dimension.csv', index = False)
date_dim.to_csv('date_dimention.csv', index = False)
features_dim.to_csv('features_dimension.csv', index = False)

# %% [markdown]
# # Loading dataset to Postgresql

# %%
# Connecting to Postgresql

import psycopg2

# %%
import getpass

password = getpass.getpass()
print('password secured')
# Out:
#  ········
# password secured

# %%
import psycopg2

def get_db_connection():
    try:
        connection = psycopg2.connect(
            host='localhost',
            port=5432,
            user='postgres',
            password='chichi',
            database='Zapco_db'
        )
        print("Database connection successful!")
        return connection
    except psycopg2.OperationalError as e:
        print("OperationalError: Unable to connect to the database.")
        print(f"Details: {e}")
    except Exception as e:
        print(f"An unexpected error occurred: {e}")
    return None
    
get_db_connection()
# Out:
# Database connection successful!
# <connection object at 0x1315338b0; dsn: 'user=postgres password=xxx dbname=Zapco_db host=localhost port=5432', closed: 0>

# %%
features_dim
# Out:
#                                               features   propertyType  \
# 0    {"architectureType": "Conventional", "cooling"...  Single Family
# 1                                                   {}        Unknown
# 2                                                  NaN  Single Family
# 3    {"cooling": true, "coolingType": "Central", "e...  Single Family
# 4    {"cooling": true, "coolingType": "Central", "e...      Townhouse
# ..                                                 ...            ...
# 337  {"architectureType": "Condo / Apartment", "ext...  Single Family
# 338  {"garage": true, "garageType": "Garage", "unit...  Single Family
# 339  {"cooling": true, "coolingType": "Commercial",...  Single Family
# 340  {"architectureType": "Ranch", "cooling": true,...  Single Family
# 341  {"exteriorType": "Concrete Block", "floorCount...  Single Family
#
#                       zoning  features_id
# 0          SF-4 INDIAN TRAIL            1
# 1                    Unknown            2
# 2                    Unknown            3
# 3                         RL            4
# 4                      PD/AN            5
# ..                       ...          ...
# 337                     RSA4          338
# 338                  Unknown          339
# 339                      R1A          340
# 340                      R-1          341
# 341  0100:SINGLE FAM,GENERAL          342
#
# [342 rows x 4 columns]

# %%
def create_tables():
    conn = get_db_connection()
    cursor = conn.cursor()

    # Corrected SQL statements
    create_table_query = '''
        CREATE SCHEMA IF NOT EXISTS zapco_schema;

        DROP TABLE IF EXISTS zapco_schema.fact_table;
        DROP TABLE IF EXISTS zapco_schema.location_dim;
        DROP TABLE IF EXISTS zapco_schema.owners_dim;
        DROP TABLE IF EXISTS zapco_schema.legal_dim;
        DROP TABLE IF EXISTS zapco_schema.date_dim;
        DROP TABLE IF EXISTS zapco_schema.features_dim;

        CREATE TABLE zapco_schema.location_dim (
            county VARCHAR(300),
            zipCode INTEGER,
            formattedAddress TEXT,
            state VARCHAR(200),
            city VARCHAR(200),
            location_id INTEGER PRIMARY KEY
        );

        CREATE TABLE zapco_schema.date_dim (
            lastSaleDate TIMESTAMP,
            year FLOAT,
            month FLOAT,
            monthName TEXT,
            quarter FLOAT,
            date_id INT PRIMARY KEY
        );

        CREATE TABLE zapco_schema.features_dim (
            features TEXT, 
            propertyType TEXT,
            zoning TEXT,
            features_id INT PRIMARY KEY
        );

        CREATE TABLE zapco_schema.legal_dim (
            legalDescription TEXT,
            subdivision TEXT,
            legal_id INT PRIMARY KEY
        );

        CREATE TABLE zapco_schema.owners_dim (
            ownerName TEXT, 
            ownerOccupied FLOAT,
            owner_id INT PRIMARY KEY
        );

        CREATE TABLE zapco_schema.fact_table (
            id FLOAT PRIMARY KEY, 
            date_id INT REFERENCES zapco_schema.date_dim(date_id) ON DELETE CASCADE,
            features_id INT REFERENCES zapco_schema.features_dim(features_id) ON DELETE CASCADE,
            location_id INT REFERENCES zapco_schema.location_dim(location_id) ON DELETE CASCADE,
            owner_id INT REFERENCES zapco_schema.owners_dim(owner_id) ON DELETE CASCADE,
            legal_id INT REFERENCES zapco_schema.legal_dim(legal_id) ON DELETE CASCADE,
            bedrooms FLOAT,
            squareFootage FLOAT,
            bathrooms FLOAT, 
            lotSize FLOAT,
            lastSalePrice FLOAT,
            taxAssessment2021_Values FLOAT,
            propertyTaxes2021_Total FLOAT,
            taxAssessment2022_Values FLOAT, 
            propertyTaxes2022_Total FLOAT,
            taxAssessment2023_Values FLOAT, 
            propertyTaxes2023_Total FLOAT, 
            longitude FLOAT, 
            latitude FLOAT
        );
    '''

    try:
        print("Creating tables...")
        cursor.execute(create_table_query)
        conn.commit()
        print("Tables created successfully.")
    except Exception as e:
        print(f"Error occurred during table creation: {e}")
    finally:
        cursor.close()
        conn.close()
        print("Database connection closed.")

create_tables()
# Out:
# Database connection successful!
# Creating tables...
# Tables created successfully.
# Database connection closed.

# %%
def load_data(csv_path, table_name, column_name):
    """
    Load the data from a given CSV file into a table in the database.

    Args:
        csv_path (str): The path to the CSV file containing the data.
        table_name (str): The name of the table to load the data into.
        column_name (list[str]): The names of the columns in the table, in the order they appear in the CSV file.

    Returns:
        None
    """
    conn = get_db_connection()
    cursor = conn.cursor()
    with open(csv_path, 'r', encoding='utf-8') as file:
        reader = csv.reader(file)
        next(reader)  # Skip the header row
        for row in reader:
            # Replace 'Not available' or empty string with None for null values
            row = [None if cell in ('', 'Not available', ' ') else cell for cell in row]
            
            # Prepare placeholders for the insert statement
            placeholders = ', '.join(['%s'] * len(row))
            query = f'INSERT INTO {table_name} ({", ".join(column_name)}) VALUES ({placeholders});'
            
            # Execute the query with the row data
            cursor.execute(query, row)

    # Commit the changes to the database
    conn.commit()
    cursor.close()
    conn.close()
    print(f"Data loaded successfully into {table_name}.")

# Load data for the date table
legal_csv_path = 'legal.csv'
load_data(legal_csv_path, 'zapco_schema.legal_dim',['legal_id','subdivision', 'legalDescription', 'assessorID'])


    # Close the cursor and connection properly
    #cursor.close()
# Out:
# Database connection successful!
# ---------------------------------------------------------------------------
# UndefinedColumn                           Traceback (most recent call last)
# Cell In[111], line 37
#      35 # Load data for the date table
#      36 legal_csv_path = 'legal.csv'
# ---> 37 load_data(legal_csv_path, 'zapco_schema.legal_dim',['legal_id','subdivision', 'legalDescription', 'assessorID'])
#
# Cell In[111], line 27, in load_data(csv_path, table_name, column_name)
#      24         query = f'INSERT INTO {table_name} ({", ".join(column_name)}) VALUES ({placeholders});'
#      26         # Execute the query with the row data
# ---> 27         cursor.execute(query, row)
#      29 # Commit the changes to the database
#      30 conn.commit()
#
# UndefinedColumn: column "assessorid" of relation "legal_dim" does not exist
# LINE 1: ...gal_dim (legal_id, subdivision, legalDescription, assessorID...
#                                                              ^

# %%
#Define the columns for the fact table (assuming these match your table schema)
fact_columns = ['id', 'date_id','owner_id', 'features_id', 'location_id', 'bedrooms', 'squareFootage', 'taxAssessment2021_Values','propertyTaxes2021_Total',
                'taxAssessment2022_Values','propertyTaxes2022_Total', 'taxAssessment2023_Values', 'propertyTaxes2023_Total','bathrooms', 'lotSize', 'lastSalePrice', 'longitude', 'latitude']

# Load data for the fact table
fact_csv_path = 'property_fact.csv'
load_data(fact_csv_path, 'zapco_schema.fact_table', fact_columns)


##  Load data for the features table
features_csv_path = 'features_dimension.csv'
load_data(features_csv_path, 'zapco_schema.features_dim',['features', 'propertyType', 'zoning', 'features_id'])

#  Load data for the owner table
owner_csv_path = 'owners_dimension.csv'
load_data(owner_csv_path, 'zapco_schema.owners_dim', ['ownerName', 'ownerOccupied', 'owner_id'])

# Load data for the location table
location_csv_path = 'location_dimension.csv'
load_data(location_csv_path, 'zapco_schema.location_dim', ['county', 'zipCode', 'formattedAddress', 'state', 'city', 'location_id'])

# Load data for the date table
date_csv_path = 'date_dimension.csv'
load_data(date_csv_path, 'zapco_schema.date_dim',['date_id','lastSalePrice','year','month','monthName','quarter'])

# %%
features_csv_path = 'features_dimension.csv'
load_data(features_csv_path, 'zapco_schema.features_dim',['features', 'propertyType', 'zoning', 'feature_id'])
# Out:
# ---------------------------------------------------------------------------
# UndefinedTable                            Traceback (most recent call last)
# Cell In[94], line 2
#       1 features_csv_path = 'features_dimension.csv'
# ----> 2 load_data(features_csv_path, 'zapco_schema.features_dim',['features', 'propertyType', 'zoning', 'feature_id'])
#
# Cell In[92], line 27, in load_data(csv_path, table_name, column_name)
#      24         query = f'INSERT INTO {table_name} ({", ".join(fact_columns)}) VALUES ({placeholders});'
#      26         # Execute the query with the row data
# ---> 27         cursor.execute(query, row)
#      29 # Commit the changes to the database
#      30 conn.commit()
#
# UndefinedTable: relation "zapco_schema.features_dim" does not exist
# LINE 1: INSERT INTO zapco_schema.features_dim (id, date_id, features...
#                     ^

# %%
location_csv_path = 'location_dimension.csv'
load_data(location_csv_path, 'zapco_schema.location_dim', ['county', 'zipCode', 'formattedAddress', 'state', 'city', 'location_id'])
# Out:
# ---------------------------------------------------------------------------
# UndefinedColumn                           Traceback (most recent call last)
# Cell In[48], line 2
#       1 location_csv_path = 'location_dimension.csv'
# ----> 2 load_data(location_csv_path, 'zapco_schema.location_dim', ['county', 'zipCode', 'formattedAddress', 'state', 'city', 'location_id'])
#
# Cell In[46], line 27, in load_data(csv_path, table_name, column_name)
#      24         query = f'INSERT INTO {table_name} ({", ".join(fact_columns)}) VALUES ({placeholders});'
#      26         # Execute the query with the row data
# ---> 27         cursor.execute(query, row)
#      29 # Commit the changes to the database
#      30 conn.commit()
#
# UndefinedColumn: column "id" of relation "location_dim" does not exist
# LINE 1: INSERT INTO zapco_schema.location_dim (id, date_id, feature_...
#                                                ^

# %%
# Out:
# ---------------------------------------------------------------------------
# UndefinedColumn                           Traceback (most recent call last)
# Cell In[74], line 2
#       1 features_csv_path = 'features_dimension.csv'
# ----> 2 load_data(features_csv_path, 'zapco_schema.features_dim',['features', 'propertyType', 'zoning', 'feature_id'])
#
# Cell In[46], line 27, in load_data(csv_path, table_name, column_name)
#      24         query = f'INSERT INTO {table_name} ({", ".join(fact_columns)}) VALUES ({placeholders});'
#      26         # Execute the query with the row data
# ---> 27         cursor.execute(query, row)
#      29 # Commit the changes to the database
#      30 conn.commit()
#
# UndefinedColumn: column "id" of relation "features_dim" does not exist
# LINE 1: INSERT INTO zapco_schema.features_dim (id, date_id, feature_...
#                                                ^

# %%
 #Load data for the features table
features_csv_path = 'features_dimension.csv'
load_data(features_csv_path, 'zapco_schema.features_dim', ['features', 'propertyType', 'zoning', 'feature_id'])

owner_csv_path = 'owners_dimension.csv'
load_data(owner_csv_path, 'zapco_schema.owners_dim', ['ownerName', 'ownerOccupied', 'owner_id'])

# Load data for the location table
location_csv_path = 'location_dimension.csv'
load_data(location_csv_path, 'zapco_schema.location_dim', ['county', 'zipCode', 'formattedAddress', 'state', 'city', 'location_id'])

# Load data for the date table
date_csv_path = 'date_dimension.csv'
load_data(date_csv_path, 'zapco_schema.date_dim',['date_id','lastSalePrice','year','month','monthName','quarter'])

# Load data for the date table
legal_csv_path = 'legal_dimension.csv'
load_data(legal_csv_path, 'zapco_schema.legal_dim',['legal_id','subdivision', 'legalDescription', 'assessorID'])

# Define the columns for the fact table (assuming these match your table schema)
fact_columns = ['id', 'date_id', 'feature_id', 'location_id', 'bedrooms', 'squareFootage', 'bathrooms', 'lotSize', 'lastSalePrice', 'lastSaleDate', 'longitude', 'latitude']

# Load data for the fact table
fact_csv_path = 'property_fact.csv'
load_data(fact_csv_path, 'zapco_schema.fact_table', fact_columns)

print('congratulations Zapco api successfully extracted and loaded')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[54], line 3
#       1 #Load data for the features table
#       2 features_csv_path = '/Users/apple/Desktop/Postgresql_etl/data/features_dimension.csv'
# ----> 3 load_data(features_csv_path, 'zapco_schema.features_dim', ['features', 'propertyType', 'zoning', 'feature_id'])
#       5 # Load data for the location table
#       6 location_csv_path = '/Users/apple/Desktop/Postgresql_etl/data/location_dimension.csv'
#
# Cell In[46], line 15, in load_data(csv_path, table_name, column_name)
#      13 conn = get_db_connection()
#      14 cursor = conn.cursor()
# ---> 15 with open(csv_path, 'r', encoding='utf-8') as file:
#      16     reader = csv.reader(file)
#      17     next(reader)  # Skip the header row
#
# File /opt/anaconda3/lib/python3.12/site-packages/IPython/core/interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/apple/Desktop/Postgresql_etl/data/features_dimension.csv'

# %%
fact_csv_path = 'property_fact.csv'
load_data(fact_csv_path, 'zapco_schema.fact_table', fact_columns)
# Out:
# ---------------------------------------------------------------------------
# UndefinedColumn                           Traceback (most recent call last)
# Cell In[50], line 2
#       1 fact_csv_path = 'property_fact.csv'
# ----> 2 load_data(fact_csv_path, 'zapco_schema.fact_table', fact_columns)
#
# Cell In[46], line 27, in load_data(csv_path, table_name, column_name)
#      24         query = f'INSERT INTO {table_name} ({", ".join(fact_columns)}) VALUES ({placeholders});'
#      26         # Execute the query with the row data
# ---> 27         cursor.execute(query, row)
#      29 # Commit the changes to the database
#      30 conn.commit()
#
# UndefinedColumn: column "owner_id" of relation "fact_table" does not exist
# LINE 1: ...fact_table (id, date_id, feature_id, location_id, owner_id, ...
#                                                              ^
